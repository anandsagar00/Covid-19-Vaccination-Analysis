# %%
import numpy as np,pandas as pd

# %%
df=pd.read_csv("country_vaccinations_by_manufacturer.csv")

# %%
df.head()
# Out:
#     location        date             vaccine  total_vaccinations
# 0  Argentina  2020-12-29             Moderna                   2
# 1  Argentina  2020-12-29  Oxford/AstraZeneca                   3
# 2  Argentina  2020-12-29   Sinopharm/Beijing                   1
# 3  Argentina  2020-12-29           Sputnik V               20481
# 4  Argentina  2020-12-30             Moderna                   2

# %%
pd.get_dummies(df,columns=['vaccine'])
# Out:
#              location        date  total_vaccinations  vaccine_CanSino  \
# 0           Argentina  2020-12-29                   2                0
# 1           Argentina  2020-12-29                   3                0
# 2           Argentina  2020-12-29                   1                0
# 3           Argentina  2020-12-29               20481                0
# 4           Argentina  2020-12-30                   2                0
# ...               ...         ...                 ...              ...
# 35618  European Union  2022-03-29            67403106                0
# 35619  European Union  2022-03-29           600519998                0
# 35620  European Union  2022-03-29             2301516                0
# 35621  European Union  2022-03-29                1809                0
# 35622  European Union  2022-03-29             1845103                0
#
#        vaccine_Covaxin  vaccine_Johnson&Johnson  vaccine_Moderna  \
# ...
