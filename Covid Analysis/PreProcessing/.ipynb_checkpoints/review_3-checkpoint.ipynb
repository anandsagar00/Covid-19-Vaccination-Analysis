# %%
import pandas as pd,matplotlib.pyplot as plt,seaborn as sns,missingno as msno,numpy as np

# %%
df=pd.read_csv('final_data_o.csv')

# %%
cols=df.columns

# %%
cols=cols[:len(cols)-10]

# %%
df=df[cols]

# %%
msno.matrix(df)

# %%
null_amount=df.isnull().sum()
null_amount[null_amount>0]
# Out:
# continent                              10385
# positive_rate                            712
# population                              1108
# female_smokers                          1559
# male_smokers                            1559
# total_cases_log                         6326
# total_deaths_log                          28
# new_tests_log                         105834
# population_density_log                 19350
# total_vaccinations_in_million            364
# people_vaccinated_in_million             364
# people_fully_vaccinated_in_million       442
# new_vaccinations_in_million              458
# dtype: int64

# %%
df.fillna(method='pad',inplace=True)

# %%
null_amount=df.isnull().sum()
null_amount[null_amount>0]
# Out:
# positive_rate                          712
# female_smokers                        1559
# male_smokers                          1559
# total_deaths_log                        28
# new_tests_log                         1559
# total_vaccinations_in_million          364
# people_vaccinated_in_million           364
# people_fully_vaccinated_in_million     442
# new_vaccinations_in_million            458
# dtype: int64

# %%
df.fillna(method='bfill',inplace=True)

# %%
df.to_csv('review_3_data.csv',index=False)
