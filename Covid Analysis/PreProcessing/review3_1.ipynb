# %%
import numpy as np,pandas as pd,matplotlib.pyplot as plt,seaborn as sns

# %%
df=pd.read_csv('review_3_data.csv',index_col='date',parse_dates=True)

# %%
df.shape
# Out:
# (177143, 28)

# %%
#We can see that there are 0 NULL values in our dataset , we had dealt  with those in pre-processing step
(df.isnull().sum()).sum()
# Out:
# 0

# %%
df.head()
# Out:
#            iso_code continent     location  positive_rate  stringency_index  \
# date
# 2020-02-24      AFG      Asia  Afghanistan         1.4855              8.33
# 2020-02-25      AFG      Asia  Afghanistan         1.4855              8.33
# 2020-02-26      AFG      Asia  Afghanistan         1.4855              8.33
# 2020-02-27      AFG      Asia  Afghanistan         1.4855              8.33
# 2020-02-28      AFG      Asia  Afghanistan         1.4855              8.33
#
#             population  median_age  aged_65_older  aged_70_older  \
# date
# 2020-02-24  39835428.0        18.6          2.581          1.337
# 2020-02-25  39835428.0        18.6          2.581          1.337
# 2020-02-26  39835428.0        18.6          2.581          1.337
# 2020-02-27  39835428.0        18.6          2.581          1.337
# 2020-02-28  39835428.0        18.6          2.581          1.337
#
#             gdp_per_capita  ...  total_deaths_log  new_deaths_log  \
# date                        ...
# ...

# %%
df1=df.copy()

# %%
from matplotlib.pyplot import figure
# %matplotlib inline

# %%
dff=df1[df1.location=='India']
figure(figsize=(2560/200,1600/200), dpi=200)
sns.lineplot(x='date',y='new_vaccinations_in_million',data=dff,label='new_vaccinations_in_million')
# list_date=list(dff.date.unique())
# plt.legend(loc=0)
# plt.xticks(list_date[0:len(list_date):50],rotation=45)
plt.title("new_vaccinations_in_million")
# Out:
# Text(0.5, 1.0, 'new_vaccinations_in_million')

# %%
dff.head()
# Out:
#            iso_code continent location  positive_rate  stringency_index  \
# date
# 2020-01-30      IND      Asia    India         1.1998             10.19
# 2020-01-31      IND      Asia    India         1.1998             10.19
# 2020-02-01      IND      Asia    India         1.1998             10.19
# 2020-02-02      IND      Asia    India         1.1998             10.19
# 2020-02-03      IND      Asia    India         1.1998             10.19
#
#               population  median_age  aged_65_older  aged_70_older  \
# date
# 2020-01-30  1.393409e+09        28.2          5.989          3.414
# 2020-01-31  1.393409e+09        28.2          5.989          3.414
# 2020-02-01  1.393409e+09        28.2          5.989          3.414
# 2020-02-02  1.393409e+09        28.2          5.989          3.414
# 2020-02-03  1.393409e+09        28.2          5.989          3.414
#
#             gdp_per_capita  ...  total_deaths_log  new_deaths_log  \
# date                        ...
# ...

# %%
dff.drop(columns=['iso_code','continent','location'],inplace=True)
# Out:
# /Users/anandsagar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dff.columns
# Out:
# Index(['positive_rate', 'stringency_index', 'population', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'life_expectancy', 'human_development_index',
#        'new_cases_log', 'total_cases_log', 'total_deaths_log',
#        'new_deaths_log', 'total_tests_log', 'new_tests_log',
#        'population_in_million_log', 'population_density_log',
#        'total_vaccinations_in_million', 'people_vaccinated_in_million',
#        'people_fully_vaccinated_in_million', 'new_vaccinations_in_million'],
#       dtype='object')

# %%
dff['new vaccinations in million']=dff['new_vaccinations_in_million']
# Out:
# <ipython-input-12-f5caffa0708c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff['new vaccinations in million']=dff['new_vaccinations_in_million']

# %%
dff.drop(columns=['new_vaccinations_in_million'],axis=1,inplace=True)

# %%
dff.corr()
# Out:
#                                     positive_rate  stringency_index  \
# positive_rate                            1.000000         -0.162673
# stringency_index                        -0.162673          1.000000
# population                                    NaN               NaN
# median_age                                    NaN               NaN
# aged_65_older                                 NaN               NaN
# aged_70_older                                 NaN               NaN
# gdp_per_capita                                NaN               NaN
# cardiovasc_death_rate                         NaN               NaN
# diabetes_prevalence                           NaN               NaN
# female_smokers                                NaN               NaN
# male_smokers                                  NaN               NaN
# life_expectancy                               NaN               NaN
# human_development_index                       NaN               NaN
# ...
