# %%
import numpy as np,pandas as pd,matplotlib.pyplot as plt,seaborn as sns

# %%
df=pd.read_csv("https://raw.githubusercontent.com/UNDP-Data/Vaccine-Equity-Dashboard-Data/main/Data.csv")

# %%
df
# Out:
#                      countryname iso3                    incomegroup  \
# 0                          Aruba  ABW          High Income Economies
# 1                    Afghanistan  AFG           Low Income Economies
# 2                         Angola  AGO  Lower Middle Income Economies
# 3                       Anguilla  AIA         Unclassified Economies
# 4                  Åland Islands  ALA                            NaN
# ..                           ...  ...                            ...
# 250  Kosovo (as per UNSCR 1244)'  XKX                            NaN
# 251                        Yemen  YEM           Low Income Economies
# 252                 South Africa  ZAF  Upper Middle Income Economies
# 253                       Zambia  ZMB  Lower Middle Income Economies
# 254                     Zimbabwe  ZWE  Lower Middle Income Economies
#
#      y2021GGXWDG_NGDP  y2021NGDPDPC    hdi  un_population2020   pop_total  \
# ...

# %%
df.columns
# Out:
# Index(['countryname', 'iso3', 'incomegroup', 'y2021GGXWDG_NGDP',
#        'y2021NGDPDPC', 'hdi', 'un_population2020', 'pop_total',
#        'vaccinesdelivered', 'deliveredpopulation', 'vaccinesdelivered_lag',
#        'informcovid19risk', 'covid19riskclass', 'gap_percapita', 'gap_gghe',
#        'uhc', 'che', 'h7_vaccinationpolicy', 'e4_internationalsupport',
#        'h5_investmentinvaccines', 'stringencyindex', 'economicsupportindex',
#        'h7_name', 'total_vaccinations', 'persons_vaccinated_1plus_dose',
#        'total_vaccinations_per100', 'persons_vaccinated_1plus_dose_pe',
#        'persons_fully_vaccinated', 'persons_fully_vaccinated_per100',
#        'vaccines_used', 'number_vaccines_types_used', 'first_vaccine_date',
#        'new_cases', 'cumulative_cases', 'new_deaths', 'cumulative_deaths',
#        'casescumulativetotal', 'casescumulativetotalper100000pop',
#        'casesnewlyreportedinlast7daysper', 'deathscumulativetotal',
# ...
